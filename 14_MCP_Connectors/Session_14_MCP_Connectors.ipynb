# %% [markdown]
# # Session 14: MCP-Powered X Post Summarizer
#
# ## Building a LangGraph Agent with GitHub MCP Tools, X API Tools, and Memory
#
# ## Learning Objectives:
#
# - **Ingest MCP servers as LangGraph tools** using `langchain-mcp-adapters` to connect to the GitHub MCP Server and use its tools programmatically
# - **Wrap the X (Twitter) API as a LangChain tool** using the `@tool` decorator so a LangGraph agent can search and retrieve public posts
# - **Build a LangGraph agent with memory** that combines MCP-sourced tools and custom tools, using `MemorySaver` for short-term conversational memory
# - **Orchestrate a full workflow through the agent** — search X posts, generate summaries, create a GitHub repo, commit files, branch, and open a PR — all via natural language
#
# ## Overview
#
# In this notebook, you will build a **LangGraph ReAct agent** that has access to two categories of tools:
#
# 1. **GitHub MCP tools** — loaded from the official GitHub MCP Server via `langchain-mcp-adapters`. These replace manual `git` commands with tool calls the agent can invoke (create repos, commit files, create branches, open PRs).
# 2. **X API tools** — custom Python functions wrapped with the `@tool` decorator that call the X API v2 directly to search and retrieve posts.
#
# The agent uses **`MemorySaver`** for short-term memory so it can maintain context across multi-step workflows within a conversation thread.
#
# There will be one breakout room with two phases:
#
# - 🤝 Phase 1: Setup, Tools & Agent Construction
#   - Task 1: Dependencies & Environment
#   - Task 2: X API as LangChain Tools
#   - Task 3: Connect to GitHub MCP Server & Load Tools
#   - Task 4: Build the LangGraph Agent with Memory
#   - Task 5: Test the Agent — Search & Summarize X Posts
#   - Activity #1: Extend the Agent with a Custom X API Tool
# - 🤝 Phase 2: MCP Workflow Through the Agent
#   - Task 6: Create a GitHub Repository
#   - Task 7: Commit the Summary
#   - Task 8: Create a Feature Branch & Add Metadata
#   - Task 9: Open a Pull Request
#   - Task 10: Commit the X API Script
#   - Task 11: Update the README
#   - Activity #1: Multi-Account Comparison Pipeline

# %% [markdown]
# ---
#
# # 🤝 Breakout Room
# ## Setup, Tools & Agent Construction

# %% [markdown]
# ## Task 1: Dependencies & Environment
#
# We need:
# - `langchain-mcp-adapters` to connect to MCP servers and convert their tools into LangChain tools
# - `langgraph` for our agent graph with memory
# - `langchain-openai` for our LLM
# - `requests` for the X API calls
# - `nest-asyncio` for async MCP operations inside Jupyter
#
# > NOTE: Create a `.env` file in this directory with `X_BEARER_TOKEN`, `OPENAI_API_KEY`, and `GITHUB_PAT` before running.
# >
# > Setup references:
# > - GitHub fine-grained PAT guide: [Creating a personal access token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens#creating-a-fine-grained-personal-access-token)
# > - X API Bearer Token setup: [X Developer Portal](https://developer.x.com/en/portal/dashboard) and [X API access tiers](https://developer.x.com/en/products/twitter-api)

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\Users\SinhaK\AppData\Local\miniconda3\envs\MCP_Env\Lib\site-packages (26.0.1)

# %%
# !py -m pip install --upgrade pip jupyterlab ipykernel requests python-dotenv nest-asyncio pip-system-certs langchain-core langchain-openai langgraph langchain-mcp-adapters
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (26.0.1)
# Requirement already satisfied: jupyterlab in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (4.5.5)
# Requirement already satisfied: ipykernel in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (7.2.0)
# Requirement already satisfied: requests in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (2.32.5)
# Requirement already satisfied: python-dotenv in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (1.2.2)
# Requirement already satisfied: nest-asyncio in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (1.6.0)
# Requirement already satisfied: pip-system-certs in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (5.3)
# Requirement already satisfied: langchain-core in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (1.2.17)
# Requirement already satisfied: langchain-openai in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (1.1.10)
# Requirement already satisfied: langgraph in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (1.0.10)
# Requirement already satisfied: langchain-mcp-adapters in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (0.2.1)
# Requirement already satisfied: async-lru>=1.0.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (2.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (26.0)
# Requirement already satisfied: setuptools>=41.1.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (82.0.0)
# Requirement already satisfied: tornado>=6.2.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (6.5.4)
# Requirement already satisfied: traitlets in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.25.0->jupyterlab) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.25.0->jupyterlab) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.25.0->jupyterlab) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (3.0.3)
# Requirement already satisfied: pyzmq>=24 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.9.0)
# Requirement already satisfied: babel>=2.10 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.26.0)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (9.10.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: psutil>=5.7 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from requests) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from requests) (2.6.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (0.7.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.20.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-openai) (2.24.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.2.28)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langgraph) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langgraph) (0.3.8)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: mcp>=1.9.2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from langchain-mcp-adapters) (1.26.0)
# Requirement already satisfied: argon2-cffi-bindings in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-core->jupyterlab) (4.9.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.0.0)
# Requirement already satisfied: rfc3339-validator in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (25.10.0)
# Requirement already satisfied: httpx-sse>=0.4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.0.22)
# Requirement already satisfied: pywin32>=310 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (3.3.2)
# Requirement already satisfied: starlette>=0.27 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.52.1)
# Requirement already satisfied: uvicorn>=0.31.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.41.0)
# Requirement already satisfied: beautifulsoup4 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.3.0)
# Requirement already satisfied: defusedxml in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: webencodings in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.2)
# Requirement already satisfied: cryptography>=3.4.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (3.0)
# Requirement already satisfied: six>=1.5 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: click>=7.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from uvicorn>=0.31.1->mcp>=1.9.2->langchain-mcp-adapters) (8.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: tzdata in C:\Users\SinhaK\AppData\Roaming\Python\Python314\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (2025.2)

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("X_BEARER_TOKEN"):
    os.environ["X_BEARER_TOKEN"] = getpass.getpass("Enter your X Bearer Token:")

if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

if not os.environ.get("GITHUB_PAT"):
    os.environ["GITHUB_PAT"] = getpass.getpass("Enter your GitHub PAT:")

# %%
import nest_asyncio
nest_asyncio.apply()  # Required for async operations in Jupyter

# %% [markdown]
# ### Getting Your Credentials
#
# **GitHub PAT (fine-grained):**
# 1. Open [GitHub Personal Access Tokens (fine-grained)](https://github.com/settings/personal-access-tokens/new).
# 2. Follow [GitHub's PAT setup guide](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens#creating-a-fine-grained-personal-access-token).
# 3. Set repository permissions to at least:
#    - `Contents`: Read and write
#    - `Pull requests`: Read and write
#    - `Metadata`: Read-only
#
# **X Bearer Token:**
# 1. Open the [X Developer Portal](https://developer.x.com/en/portal/dashboard).
# 2. Create/select a Project + App, then go to **Keys and Tokens** to generate a Bearer Token.
# 3. Confirm your plan supports the recent search endpoint (`GET /2/tweets/search/recent`) from the [X API product page](https://developer.x.com/en/products/twitter-api).

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

# Test the connection
response = llm.invoke("Say 'MCP agent ready!' in exactly those words.")
print(response.content)
# Out:
# MCP agent ready!

# %% [markdown]
# ## Task 2: X API as LangChain Tools
#
# Instead of relying on a community-built MCP server for X, we'll call the **X API v2** directly and wrap our functions with the `@tool` decorator. This makes them available to our LangGraph agent as callable tools — just like the MCP tools will be.
#
# This is a key architectural decision: **not everything needs to be an MCP server**. Wrapping a simple API call as a `@tool` is often simpler and more transparent.
#
# **📚 Documentation:**
# - [LangChain Tools Conceptual Guide](https://python.langchain.com/docs/concepts/tools/)
# - [X API v2 Documentation](https://developer.x.com/en/docs/x-api)

# %%
import requests
import json
from langchain_core.tools import tool

BEARER_TOKEN = os.environ.get("X_BEARER_TOKEN")


@tool
def search_recent_posts(query: str, max_results: int = 20) -> str:
    """Search recent X/Twitter posts using the v2 API.
    Returns posts from the last 7 days matching the query.
    Use this for keyword searches, hashtag searches, or general topic searches.

    Args:
        query: The search query (e.g., 'AI safety', '#machinelearning', 'from:AndrewYNg')
        max_results: Number of results to return (10-100, default 20)
    """
    url = "https://api.x.com/2/tweets/search/recent"
    headers = {"Authorization": f"Bearer {BEARER_TOKEN}"}
    params = {
        "query": query,
        "max_results": min(max(max_results, 10), 100),
        "tweet.fields": "created_at,public_metrics,author_id,text",
        "expansions": "author_id",
        "user.fields": "name,username",
    }

    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    data = response.json()

    tweets = data.get("data", [])
    if not tweets:
        return "No posts found for this query."

    result_lines = [f"Found {len(tweets)} posts:\n"]
    for t in tweets:
        metrics = t.get("public_metrics", {})
        result_lines.append(
            f"[{t.get('created_at', 'unknown')[:10]}] "
            f"{t['text'][:200]}\n"
            f"  Likes: {metrics.get('like_count', 0)} | "
            f"Retweets: {metrics.get('retweet_count', 0)}"
        )
    return "\n\n".join(result_lines)


@tool
def get_user_posts(username: str, max_results: int = 20) -> str:
    """Get recent original posts (no retweets) from a specific X/Twitter user.
    Use this when you want to see what a specific account has been posting.

    Args:
        username: The X/Twitter handle without the @ sign (e.g., 'AndrewYNg')
        max_results: Number of results to return (10-100, default 20)
    """
    query = f"from:{username} -is:retweet"
    return search_recent_posts.invoke({"query": query, "max_results": max_results})


x_api_tools = [search_recent_posts, get_user_posts]
print(f"Created {len(x_api_tools)} X API tools: {[t.name for t in x_api_tools]}")
# Out:
# Created 2 X API tools: ['search_recent_posts', 'get_user_posts']

# %% [markdown]
# Let's verify our X API tools work before wiring them into the agent:

# %%
import os

CA_BUNDLE = r"C:\Users\SinhaK\AppData\Local\miniconda3\Lib\site-packages\certifi\cacert.pem"

os.environ["REQUESTS_CA_BUNDLE"] = CA_BUNDLE
os.environ["CURL_CA_BUNDLE"] = CA_BUNDLE

print("REQUESTS_CA_BUNDLE =", os.environ["REQUESTS_CA_BUNDLE"])
print("CURL_CA_BUNDLE =", os.environ["CURL_CA_BUNDLE"])
# Out:
# REQUESTS_CA_BUNDLE = C:\Users\SinhaK\AppData\Local\miniconda3\Lib\site-packages\certifi\cacert.pem
# CURL_CA_BUNDLE = C:\Users\SinhaK\AppData\Local\miniconda3\Lib\site-packages\certifi\cacert.pem

# %%
# Quick test — fetch recent posts from a public account
result = get_user_posts.invoke({"username": "thysel55307", "max_results": 10})
print(result[:500])
# Out:
# Found 2 posts:
#
#
# [2026-03-06] Built an Advanced Retrieval with LangChain notebook and compared multiple RAG retrieval strategies on a health &amp; wellness corpus.
#
# Covered:
#
# 1. Naive vector retrieval
# 2. BM25
# 3. Contextual compres
#   Likes: 0 | Retweets: 0
#
# [2026-03-02] Just recorded a walkthrough of 2 Jupyter notebooks where I evaluate:
#
# 👉RAG systems with Ragas
# 👉Tool-using agents with Ragas Agent metrics
#
# Notebook 1:
#
# Chunking + overlap
#
# Baseline vs improved RAG
#
# Wh
#   Likes: 0 | Retweets: 0

# %% [markdown]
# ## Task 3: Connect to GitHub MCP Server & Load Tools
#
# Now we'll connect to the **GitHub MCP Server** — an official, GitHub-maintained MCP server that gives agents the ability to manage repositories, issues, pull requests, and more.
#
# We use `langchain-mcp-adapters` to:
# 1. Connect to the remote GitHub MCP server over HTTP
# 2. Automatically convert all MCP tools into LangChain-compatible tools
#
# This is the key MCP integration point — instead of writing custom GitHub API wrappers, we get a full set of tools for free just by connecting to the MCP server.
#
# **📚 Documentation:**
# - [langchain-mcp-adapters](https://github.com/langchain-ai/langchain-mcp-adapters)
# - [GitHub MCP Server](https://github.com/github/github-mcp-server)
# - [Model Context Protocol Specification](https://modelcontextprotocol.io/)

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

# Connect to the GitHub MCP server using Streamable HTTP transport
# The server exposes GitHub operations as MCP tools that our agent can call
mcp_client = MultiServerMCPClient(
    {
        "github": {
            "transport": "http",
            "url": "https://api.githubcopilot.com/mcp/",
            "headers": {
                "Authorization": f"Bearer {os.environ['GITHUB_PAT']}",
            },
        }
    }
)

# Load all tools from the MCP server
github_mcp_tools = await mcp_client.get_tools()

print(f"Loaded {len(github_mcp_tools)} GitHub MCP tools:\n")
for t in github_mcp_tools:
    print(f"  - {t.name}: {t.description[:80]}...")
# Out:
# Loaded 43 GitHub MCP tools:
#
#   - add_comment_to_pending_review: Add review comment to the requester's latest pending pull request review. A pend...
#   - add_issue_comment: Add a comment to a specific issue in a GitHub repository. Use this tool to add c...
#   - add_reply_to_pull_request_comment: Add a reply to an existing pull request comment. This creates a new comment that...
#   - assign_copilot_to_issue: Assign Copilot to a specific issue in a GitHub repository.
#
# This tool can help w...
#   - create_branch: Create a new branch in a GitHub repository...
#   - create_or_update_file: Create or update a single file in a GitHub repository.
# If updating, you should ...
#   - create_pull_request: Create a new pull request in a GitHub repository....
#   - create_pull_request_with_copilot: Delegate a task to GitHub Copilot coding agent to perform in the background. The...
#   - create_repository: Create a new GitHub repository in your account or specified organization...
#   - delete_file: Delete a file from a GitHub repository...
#   - fork_repository: Fork a GitHub repository to your account or specified organization...
#   - get_commit: Get details for a commit from a GitHub repository...
#   - get_copilot_job_status: Get the status of a GitHub Copilot coding agent job. Use this to check if a prev...
#   - get_file_contents: Get the contents of a file or directory from a GitHub repository...
#   - get_label: Get a specific label from a repository....
#   - get_latest_release: Get the latest release in a GitHub repository...
#   - get_me: Get details of the authenticated GitHub user. Use this when a request is about t...
#   - get_release_by_tag: Get a specific release by its tag name in a GitHub repository...
#   - get_tag: Get details about a specific git tag in a GitHub repository...
#   - get_team_members: Get member usernames of a specific team in an organization. Limited to organizat...
#   - get_teams: Get details of the teams the user is a member of. Limited to organizations acces...
#   - issue_read: Get information about a specific issue in a GitHub repository....
#   - issue_write: Create a new or update an existing issue in a GitHub repository....
#   - list_branches: List branches in a GitHub repository...
#   - list_commits: Get list of commits of a branch in a GitHub repository. Returns at least 30 resu...
#   - list_issue_types: List supported issue types for repository owner (organization)....
#   - list_issues: List issues in a GitHub repository. For pagination, use the 'endCursor' from the...
#   - list_pull_requests: List pull requests in a GitHub repository. If the user specifies an author, then...
#   - list_releases: List releases in a GitHub repository...
#   - list_tags: List git tags in a GitHub repository...
#   - merge_pull_request: Merge a pull request in a GitHub repository....
#   - pull_request_read: Get information on a specific pull request in GitHub repository....
#   - pull_request_review_write: Create and/or submit, delete review of a pull request.
#
# Available methods:
# - cre...
#   - push_files: Push multiple files to a GitHub repository in a single commit...
#   - request_copilot_review: Request a GitHub Copilot code review for a pull request. Use this for automated ...
#   - search_code: Fast and precise code search across ALL GitHub repositories using GitHub's nativ...
#   - search_issues: Search for issues in GitHub repositories using issues search syntax already scop...
#   - search_pull_requests: Search for pull requests in GitHub repositories using issues search syntax alrea...
#   - search_repositories: Find GitHub repositories by name, description, readme, topics, or other metadata...
#   - search_users: Find GitHub users by username, real name, or other profile information. Useful f...
#   - sub_issue_write: Add a sub-issue to a parent issue in a GitHub repository....
#   - update_pull_request: Update an existing pull request in a GitHub repository....
#   - update_pull_request_branch: Update the branch of a pull request with the latest changes from the base branch...

# %% [markdown]
# ### Key GitHub MCP Tools
#
# The MCP server exposes many tools, but the key ones we'll use are:
#
# | MCP Tool | Replaces (Git CLI) | What It Does |
# |---|---|---|
# | `create_repository` | `git init` + GitHub UI | Creates a new repo on your account |
# | `create_or_update_file` | `git add` + `git commit` + `git push` | Commits a file directly to a branch |
# | `create_branch` | `git checkout -b` | Creates a new branch |
# | `create_pull_request` | `gh pr create` | Opens a PR from one branch to another |
# | `search_repositories` | `gh repo list` | Searches across your repos |
# | `get_file_contents` | `git show` / `cat` | Reads a file from a repo |
# | `list_commits` | `git log` | Shows commit history |

# %% [markdown]
# ## Task 4: Build the LangGraph Agent with Memory
#
# Now we combine **both tool sets** into a single LangGraph agent:
# - **X API tools** — custom `@tool` functions for searching posts
# - **GitHub MCP tools** — loaded from the MCP server via `langchain-mcp-adapters`
#
# We add **`MemorySaver`** for short-term memory so the agent remembers context across the multi-step workflow (e.g., it fetches posts in one turn, summarizes them in the next, and commits the summary in a third).
#
# The architecture follows the standard LangGraph ReAct pattern from Sessions 4-6:
#
# ```
# ┌─────────┐     ┌───────────┐
# │  START   │────▶│   Agent   │◀──────────────┐
# └─────────┘     │  (LLM +   │               │
#                 │   tools)  │               │
#                 └─────┬─────┘               │
#                       │                     │
#                has tool calls?              │
#                 /           \               │
#               yes            no             │
#               /               \             │
#     ┌─────────────┐     ┌─────────┐        │
#     │  Tool Node  │     │   END   │        │
#     │ (X API +    │     └─────────┘        │
#     │  GitHub MCP)│─────────────────────────┘
#     └─────────────┘
# ```
#
# **📚 Documentation:**
# - [LangGraph ReAct Agent](https://langchain-ai.github.io/langgraph/tutorials/introduction/)
# - [MemorySaver (Checkpointing)](https://langchain-ai.github.io/langgraph/concepts/persistence/)
# - [ToolNode Prebuilt](https://langchain-ai.github.io/langgraph/reference/prebuilt/#langgraph.prebuilt.tool_node.ToolNode)

# %%
from typing import Annotated, Literal
from typing_extensions import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

# Combine all tools: X API tools + GitHub MCP tools
all_tools = x_api_tools + github_mcp_tools
print(f"Total tools available to agent: {len(all_tools)}")
print(f"  X API tools: {[t.name for t in x_api_tools]}")
print(f"  GitHub MCP tools: {[t.name for t in github_mcp_tools]}")
# Out:
# Total tools available to agent: 45
#   X API tools: ['search_recent_posts', 'get_user_posts']
#   GitHub MCP tools: ['add_comment_to_pending_review', 'add_issue_comment', 'add_reply_to_pull_request_comment', 'assign_copilot_to_issue', 'create_branch', 'create_or_update_file', 'create_pull_request', 'create_pull_request_with_copilot', 'create_repository', 'delete_file', 'fork_repository', 'get_commit', 'get_copilot_job_status', 'get_file_contents', 'get_label', 'get_latest_release', 'get_me', 'get_release_by_tag', 'get_tag', 'get_team_members', 'get_teams', 'issue_read', 'issue_write', 'list_branches', 'list_commits', 'list_issue_types', 'list_issues', 'list_pull_requests', 'list_releases', 'list_tags', 'merge_pull_request', 'pull_request_read', 'pull_request_review_write', 'push_files', 'request_copilot_review', 'search_code', 'search_issues', 'search_pull_requests', 'search_repositories', 'search_users', 'sub_issue_write', 'update_pull_request', 'update_pull_request_branch']

# %%
# Step 1: Define the Agent State
class AgentState(TypedDict):
    messages: Annotated[list, add_messages]


# Step 2: Define the system prompt
SYSTEM_PROMPT = """You are an AI assistant that can search X/Twitter posts and manage GitHub repositories.

You have two categories of tools:
1. X API tools: search_recent_posts, get_user_posts — for searching and retrieving X/Twitter posts
2. GitHub MCP tools: for creating repos, committing files, creating branches, opening PRs, etc.

When asked to summarize posts, retrieve them first using the X API tools, then provide a structured
markdown summary with: Overview, Key Themes, Notable Posts, and Summary Statistics.

When asked to perform GitHub operations, use the appropriate GitHub MCP tool.
Always use the available tools when appropriate. Be concise in your responses."""


# Step 3: Bind tools to the LLM
llm_with_tools = llm.bind_tools(all_tools)


# Step 4: Define the agent node
def agent_node(state: AgentState):
    """The agent node — calls the LLM with the current conversation and available tools."""
    messages = [SystemMessage(content=SYSTEM_PROMPT)] + state["messages"]
    response = llm_with_tools.invoke(messages)
    return {"messages": [response]}


# Step 5: Define the tool node
tool_node = ToolNode(all_tools, handle_tool_errors=True)


# Step 6: Define routing logic
def should_continue(state: AgentState) -> Literal["tools", "end"]:
    """Determine whether to call tools or end the conversation."""
    last_message = state["messages"][-1]
    if hasattr(last_message, "tool_calls") and last_message.tool_calls:
        return "tools"
    return "end"


# Step 7: Build the graph
workflow = StateGraph(AgentState)

workflow.add_node("agent", agent_node)
workflow.add_node("tools", tool_node)

workflow.add_edge(START, "agent")
workflow.add_conditional_edges("agent", should_continue, {"tools": "tools", "end": END})
workflow.add_edge("tools", "agent")

# Compile with MemorySaver for short-term memory across turns
checkpointer = MemorySaver()
agent = workflow.compile(checkpointer=checkpointer)

print("Agent compiled with memory and tools!")
# Out:
# Agent compiled with memory and tools!

# %% [markdown]
# Let's visualize the graph to confirm our architecture:

# %%
from IPython.display import Image, display

display(Image(agent.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Helper function for running the agent
#
# We'll use a single `thread_id` throughout the notebook so the agent remembers previous interactions (short-term memory via the checkpointer).

# %%
# Use a consistent thread_id so the agent remembers context across all tasks
config = {"configurable": {"thread_id": "mcp-workflow-1"}}


async def ask_agent(user_message: str) -> str:
    """Send a message to the agent and return its final response."""
    response = await agent.ainvoke(
        {"messages": [HumanMessage(content=user_message)]},
        config,
    )
    return response["messages"][-1].content

# %% [markdown]
# ## Task 5: Test the Agent — Search & Summarize X Posts
#
# Let's put the agent through its paces. First, we'll ask it to search for posts and generate a summary. Because we're using `MemorySaver` with a consistent `thread_id`, the agent will remember the posts it found when we ask it to summarize them.

# %%
# Ask the agent to fetch posts — it will use the get_user_posts tool
result = await ask_agent("Get recent posts from @thysel55307 on X/Twitter.")
print(result[:1000])
# Out:
# Here are the recent posts from @thysel55307 on X/Twitter:
#
# 1. (2026-03-06) Built an Advanced Retrieval with LangChain notebook and compared multiple RAG retrieval strategies on a health & wellness corpus. Covered naive vector retrieval, BM25, and contextual compression.
# 2. (2026-03-02) Recorded a walkthrough of 2 Jupyter notebooks evaluating RAG systems with Ragas and tool-using agents with Ragas Agent metrics. Discussed chunking, overlap, baseline vs improved RAG.
#
# Let me know if you want more details or a summary.

# %%
# Ask the agent to summarize — it remembers the posts from the previous turn!
summary = await ask_agent(
    "Now summarize those posts into a structured markdown report with sections for: "
    "Overview, Key Themes, Notable Posts, and Summary Statistics. "
    "Format it so it can be saved directly as a summary.md file."
)
print(summary)
# Out:
# ```markdown
# # Summary of Recent Posts from @thysel55307
#
# ## Overview
# @thysel55307 has recently shared insights and work related to Retrieval-Augmented Generation (RAG) systems and advanced retrieval strategies using LangChain. The posts focus on technical evaluations and comparisons of different retrieval methods and agent metrics within the context of health and wellness data.
#
# ## Key Themes
# - Advanced retrieval techniques in natural language processing
# - Use of LangChain for building retrieval notebooks
# - Comparison of multiple RAG retrieval strategies including naive vector retrieval, BM25, and contextual compression
# - Evaluation of RAG systems and tool-using agents with specific metrics
# - Practical walkthroughs using Jupyter notebooks for experimentation and analysis
#
# ## Notable Posts
# 1. **Advanced Retrieval with LangChain Notebook**
#    Date: 2026-03-06
#    Description: Built a notebook comparing multiple RAG retrieval strategies on a health & wellness corpus, covering naive vector retrieval, BM25, and contextual compression.
#
# 2. **Walkthrough of RAG Systems and Tool-Using Agents**
#    Date: 2026-03-02
#    Description: Recorded a walkthrough of two Jupyter notebooks evaluating RAG systems with Ragas and tool-using agents with Ragas Agent metrics, discussing chunking, overlap, and baseline vs improved RAG.
#
# ## Summary Statistics
# - Total posts analyzed: 2
# - Posts with technical content: 2
# - Topics covered: Retrieval strategies, RAG systems, LangChain, Jupyter notebooks
# - Engagement: No likes or retweets recorded on these posts
#
# ```
# This markdown report is ready to be saved as summary.md. Let me know if you want me to create the file in a repository or assist further.

# %% [markdown]
# Save the summary locally for reference:

# %%
with open("summary.md", "w") as f:
    f.write(summary)

print("Summary saved to summary.md")
# Out:
# Summary saved to summary.md

# %% [markdown]
# ### ❓ Question #1:
#
#
#
# ##### Answer:
#
# *Your answer here*

# %% [markdown]
# ### 🏗️ Activity #1:
#
# Your task is to extend the agent with a **new custom X API tool** and verify it works end-to-end.
#
# 1. **Create a new `@tool` function** called `get_user_profile` that retrieves a user's public profile information using the X API v2 [`GET /2/users/by/username/:username`](https://developer.x.com/en/docs/x-api/users/lookup/api-reference/get-users-by-username-username) endpoint. It should return:
#    - Display name
#    - Bio / description
#    - Follower count
#    - Following count
#    - Post count
#    - Account creation date
#
# 2. **Rebuild the agent** with the updated tool set — add your new tool to `x_api_tools`, re-combine with the MCP tools, re-bind tools to the LLM, and recompile the graph
#
# 3. **Test it** by asking the agent to:
#    - Retrieve the profile of an AI thought leader of your choice
#    - Compare that profile with the posts you already retrieved in Task 5 — does the bio match the posting themes?
#
# > HINT: The X API v2 user lookup endpoint uses the same Bearer Token authentication. You'll need `user.fields=description,public_metrics,created_at` in your request params.

# %%
### YOUR CODE HERE
@tool
def get_user_profile(username: str) -> str:
    """Get public profile information for a specific X/Twitter user."""
    username = username.lstrip("@").strip()

    bearer_token = os.environ.get("X_BEARER_TOKEN", "").strip()
    if not bearer_token:
        raise ValueError("X_BEARER_TOKEN is missing. Please set it before calling this tool.")

    url = f"https://api.x.com/2/users/by/username/{username}"
    headers = {"Authorization": f"Bearer {bearer_token}"}
    params = {
        "user.fields": "description,public_metrics,created_at"
    }

    response = requests.get(url, headers=headers, params=params, timeout=30)
    response.raise_for_status()

    data = response.json().get("data")
    if not data:
        return f"No profile found for @{username}."

    metrics = data.get("public_metrics", {})

    return (
        f"Profile for @{data.get('username', username)}\n"
        f"Display name: {data.get('name', 'N/A')}\n"
        f"Bio / description: {data.get('description', 'N/A')}\n"
        f"Follower count: {metrics.get('followers_count', 0)}\n"
        f"Following count: {metrics.get('following_count', 0)}\n"
        f"Post count: {metrics.get('tweet_count', 0)}\n"
        f"Account creation date: {data.get('created_at', 'N/A')}"
    )


# Rebuild the X tool list
x_api_tools = [search_recent_posts, get_user_posts, get_user_profile]

# Re-combine with GitHub MCP tools
all_tools = x_api_tools + github_mcp_tools

# Update the system prompt so the agent knows about the new tool
SYSTEM_PROMPT = """You are an AI assistant that can search X/Twitter posts, inspect X/Twitter user profiles, and manage GitHub repositories."""

# %%
# Re-bind tools to the LLM
llm_with_tools = llm.bind_tools(all_tools)

# Rebuild the tool node
tool_node = ToolNode(all_tools, handle_tool_errors=True)

# Rebuild and recompile the graph
workflow = StateGraph(AgentState)
workflow.add_node("agent", agent_node)
workflow.add_node("tools", tool_node)

workflow.add_edge(START, "agent")
workflow.add_conditional_edges("agent", should_continue, {"tools": "tools", "end": END})
workflow.add_edge("tools", "agent")

# IMPORTANT: reuse the same checkpointer so prior memory from Task 5 is still available
agent = workflow.compile(checkpointer=checkpointer)

print("Updated X API tools:", [t.name for t in x_api_tools])
print("Total tools available:", len(all_tools))


# -------------------------
# Test 1: retrieve profile
# -------------------------
profile_result = await ask_agent("Get the public X/Twitter profile for @thysel55307.")
print(profile_result)


# -------------------------
# Test 2: compare profile with Task 5 posts already in memory
# -------------------------
comparison_result = await ask_agent(
    "Compare @thysel55307's profile with the recent posts you already retrieved earlier in Task 5. "
    "Does the bio match the posting themes? Answer briefly with a clear yes/no and 3-5 supporting points."
)
print(comparison_result)
# Out:
# Updated X API tools: ['search_recent_posts', 'get_user_posts', 'get_user_profile']
# Total tools available: 46
# The public X/Twitter profile for @thysel55307 is:
#
# - Display name: Krishanu
# - Bio: I'm an AI Engineer with 7+ years of experience in LLMs, deep learning, and AI solutions. Passionate about building scalable AI systems and driving innovation.
# - Followers: 25
# - Following: 84
# - Posts: 60
# - Account created on: December 7, 2023
#
# Let me know if you need any more information.
# Yes, @thysel55307's bio matches the posting themes.
#
# Supporting points:
# 1. Posts focus on advanced retrieval techniques and RAG systems, relevant to LLMs and AI solutions.
# 2. Use of LangChain and Jupyter notebooks aligns with building scalable AI systems.
# 3. Discussion of evaluation metrics and tool-using agents reflects expertise in deep learning and AI.
# 4. Technical content matches the profile's emphasis on AI engineering and innovation.
# 5. Consistent AI-focused content supports the bio's claim of passion and specialization.

# %% [markdown]
# ---
#
# ## Phase 2: MCP Workflow Through the Agent
#
# Now we'll use the same agent to perform all GitHub repository operations through the **GitHub MCP tools**. Because the agent has memory, it already knows the summary it generated in Phase 1.
#
# Each task below sends a natural language instruction to the agent. The agent decides which GitHub MCP tool(s) to call to fulfill the request.

# %% [markdown]
# ## Task 6: Create a New Repository
#
# The agent will use the `create_repository` MCP tool to create a new repo on your GitHub account.

# %%
result = await ask_agent(
    "Using your GitHub tools, create a new public repository on my account called "
    "`x-post-summarizer-2026`. Add a description: 'AI-generated summary of a public "
    "figure's 2026 X posts, built with LangGraph, MCP tools, and the X API.' "
    "Initialize it with a README."
)
print(result)
# Out:
# I have created a new public GitHub repository named "x-post-summarizer-2026" on your account with the description: "AI-generated summary of a public figure's 2026 X posts, built with LangGraph, MCP tools, and the X API." It is initialized with a README.
#
# You can view it here: https://github.com/KrishanuSinha/x-post-summarizer-2026
#
# Let me know if you want to add any files or content to it.

# %% [markdown]
# ## Task 7: Commit the Summary to Your Repo
#
# The agent remembers the summary it generated earlier (short-term memory) and can commit it directly.

# %%
result = await ask_agent(
    "Using your GitHub tools, create a new file called `summary.md` in the "
    "`x-post-summarizer-2026` repo on the `main` branch. The file should contain "
    "the X post summary you generated earlier. Use the commit message: "
    "'Add 2026 X post summary'."
)
print(result)
# Out:
# The file summary.md containing the X post summary has been created in the x-post-summarizer-2026 repository on the main branch. The commit message used was "Add 2026 X post summary."
#
# You can view the file here: https://github.com/KrishanuSinha/x-post-summarizer-2026/blob/main/summary.md
#
# Let me know if you need any further assistance.

# %% [markdown]
# ## Task 8: Create a Feature Branch and Add Metadata
#
# The agent will use `create_branch` and `create_or_update_file` MCP tools.

# %%
result = await ask_agent(
    "Create a new branch called `add-metadata` in my `x-post-summarizer-2026` repo. "
    "On that branch, create a file called `metadata.json` that contains: the account "
    "handle analyzed, the date range of posts, the number of posts analyzed, and the "
    "top 5 themes identified from the summary. Commit it with the message "
    "'Add analysis metadata'."
)
print(result)
# Out:
# A new branch called add-metadata has been created in your x-post-summarizer-2026 repository. On that branch, I added a file named metadata.json containing the account handle analyzed, the date range of posts, the number of posts analyzed, and the top 5 themes identified from the summary. The commit message was "Add analysis metadata."
#
# You can view the file here: https://github.com/KrishanuSinha/x-post-summarizer-2026/blob/add-metadata/metadata.json
#
# Let me know if you want to proceed with anything else.

# %% [markdown]
# ## Task 9: Open a Pull Request
#
# The agent will use the `create_pull_request` MCP tool.

# %%
result = await ask_agent(
    "Open a pull request in my `x-post-summarizer-2026` repo from the `add-metadata` "
    "branch to `main`. Title it 'Add analysis metadata' and include a description "
    "summarizing what the metadata file contains."
)
print(result)
# Out:
# I have opened a pull request in your x-post-summarizer-2026 repository from the add-metadata branch to main.
#
# Title: Add analysis metadata
# Description: This pull request adds a metadata.json file containing analysis details for the X post summary. The metadata includes the account handle analyzed, the date range of posts, the number of posts analyzed, and the top 5 themes identified from the summary.
#
# You can view the pull request here: https://github.com/KrishanuSinha/x-post-summarizer-2026/pull/1
#
# Let me know if you want to do anything else.

# %% [markdown]
# ## Task 10: Commit the X API Script
#
# We'll ask the agent to commit a clean version of the X search script — reading credentials from environment variables, no hardcoded keys.

# %%
x_search_script = '''import requests
import json
import os
from datetime import datetime

BEARER_TOKEN = os.environ.get("X_BEARER_TOKEN")

def search_recent_posts(query: str, max_results: int = 20) -> dict:
    """Search recent X posts using the v2 API."""
    url = "https://api.x.com/2/tweets/search/recent"
    headers = {"Authorization": f"Bearer {BEARER_TOKEN}"}
    params = {
        "query": query,
        "max_results": min(max_results, 100),
        "tweet.fields": "created_at,public_metrics,author_id,text",
        "expansions": "author_id",
        "user.fields": "name,username",
    }
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    return response.json()

def get_user_posts(username: str, max_results: int = 20) -> dict:
    """Get recent posts from a specific user."""
    query = f"from:{username} -is:retweet"
    return search_recent_posts(query, max_results)

if __name__ == "__main__":
    import sys
    handle = sys.argv[1] if len(sys.argv) > 1 else "llM_wizard"
    print(f"Searching for recent posts from @{handle}...")
    results = get_user_posts(handle)
    with open("posts.json", "w") as f:
        json.dump(results, f, indent=2)
    tweets = results.get("data", [])
    print(f"Found {len(tweets)} posts.")
    for tweet in tweets:
        print(f"  [{tweet[\"created_at\"][:10]}] {tweet[\"text\"][:100]}...")
'''

result = await ask_agent(
    f"Using your GitHub tools, create a new file called `x_search.py` in the "
    f"`x-post-summarizer-2026` repo on the `main` branch. Use the commit message: "
    f"'Add X API search script'. Here is the file content:\n\n{x_search_script}"
)
print(result)
# Out:
# The file x_search.py containing the X API search script has been created in the x-post-summarizer-2026 repository on the main branch. The commit message used was "Add X API search script."
#
# You can view the file here: https://github.com/KrishanuSinha/x-post-summarizer-2026/blob/main/x_search.py
#
# Let me know if you need any further assistance.

# %% [markdown]
# ## Task 11: Update the README
#
# The agent already knows everything about the project from its conversation memory — what account was analyzed, how the project was built, etc.

# %%
result = await ask_agent(
    "Update the README.md in my `x-post-summarizer-2026` repo on main to include: "
    "a project description explaining this repo summarizes a public figure's 2026 X "
    "posts using AI, the handle analyzed, how the project was built (using a LangGraph "
    "agent with GitHub MCP tools for repo operations and the X API v2 for post "
    "retrieval), and instructions for someone else to replicate the process — including "
    "how to set up their X API Bearer Token and install Python dependencies."
)
print(result)
# Out:
# The README.md file in your x-post-summarizer-2026 repository on the main branch has been updated with a project description, the handle analyzed, how the project was built, and instructions for replicating the process including setting up the X API Bearer Token and installing Python dependencies.
#
# You can view the updated README here: https://github.com/KrishanuSinha/x-post-summarizer-2026/blob/main/README.md
#
# Let me know if you need any more help.

# %% [markdown]
# ### ❓ Question #2:
#
# Compare using GitHub MCP tools (through a LangGraph agent) to traditional `git` commands. What felt easier? What felt harder or less transparent?
#
# ##### Answer:
#
# *Using GitHub MCP tools through a LangGraph agent felt easier for high-level, intent-based workflows. Instead of remembering a sequence of commands, I could describe the outcome I wanted, like creating a branch, adding a file, and opening a PR, and let the agent choose from the GitHub tools exposed by the MCP server. That felt more natural and faster for multi-step automation. MCP is built around structured, named tools, and LangChain’s MultiServerMCPClient can load tools from one or more MCP servers into a unified tool registry, which makes this style of interaction possible. GitHub’s MCP server is specifically designed to expose GitHub actions to AI agents and assistants.
#
# What felt harder was transparency and debugging. Traditional git gives very direct visibility into repository state through commands like git status, git diff, and git log, so it is easier to see exactly what changed, what is staged, and what history exists. With MCP tools, some of that detail is abstracted behind the agent and server, so when something goes wrong it can be less obvious whether the problem is authentication, tool selection, server behavior, or repository state. So overall, MCP felt easier for automation and productivity, while traditional git felt better for low-level control, inspection, and troubleshooting.
# *

# %% [markdown]
# ### ❓ Question #3:
#
# You used MCP for GitHub but wrapped the X API as a `@tool` directly. What are the tradeoffs of consuming an API through an MCP server versus wrapping it as a LangChain tool? When would each approach make more sense?
#
# ##### Answer:
#
# *The main advantage of consuming an API through an MCP server is standardization and reuse. MCP is an open, model-agnostic protocol where servers expose tools with structured schemas, and LangChain adapters can load those tools into agents without writing custom wrappers for every endpoint. That makes MCP a strong choice when an integration already has a mature server, when multiple agents or clients need to share the same capability, or when you want a cleaner separation between the agent logic and the external system.
#
# The main advantage of wrapping an API directly as a LangChain @tool is control and simplicity for small use cases. In this notebook, the X API only needed a few endpoints, so writing direct tools was faster and made debugging easier because I controlled the request, headers, response parsing, and final output format myself. The tradeoff is that direct tools are more custom and less portable, because the integration logic lives inside the app instead of being exposed through a reusable protocol. In practice, I would use MCP when the integration is broad, shared, or already available as a maintained server, and use a direct @tool wrapper when the API surface is small, highly customized, or still being prototyped.
# *

# %% [markdown]
# ### 🏗️ Activity #1:
#
# Your task is to extend the MCP workflow by building a **Multi-Account Comparison Pipeline** through the agent.
#
# You are expected to:
#
# 1. **Retrieve posts from a second X account** — choose another public figure or thought leader in a related field
#
# 2. **Generate a structured comparison** by asking the agent to create a `comparison.md` file that includes:
#    - Side-by-side topic analysis for both accounts
#    - Tone and sentiment differences
#    - Posting frequency comparison
#    - Top 3 most notable posts from each account
#    - A brief conclusion about each account's focus area
#
# 3. **Commit through the MCP workflow**:
#    - Create a new branch called `add-comparison` in your `x-post-summarizer-2026` repo
#    - Commit `comparison.md` to that branch
#    - Open a pull request to merge it into `main`
#
# > NOTE: The agent already has memory of the first account's posts from Phase 1. You only need to fetch posts from the second account — the agent will use its memory for the rest.

# %%
### YOUR CODE HERE

# %%
# Activity #2 — Multi-Account Comparison Pipeline
# Comparing @narendramodi and @RahulGandhi

# Step 1: Load Narendra Modi posts into memory for this task
modi_posts = await ask_agent(
    "Use the X tools to retrieve recent original posts from @narendramodi. "
    "Give me a short summary in 5 bullets and remember these posts for a later comparison. "
    "For this task, focus only on @narendramodi and @RahulGandhi."
)
print(modi_posts[:1500])


# Step 2: Load Rahul Gandhi posts into memory for this task
rahul_posts = await ask_agent(
    "Use the X tools to retrieve recent original posts from @RahulGandhi. "
    "Give me a short summary in 5 bullets and remember these posts for a later comparison. "
    "For this task, focus only on @narendramodi and @RahulGandhi."
)
print(rahul_posts[:1500])


# Step 3: Create or reuse the comparison branch
branch_result = await ask_agent(
    "In my GitHub repository x-post-summarizer-2026, create a new branch called add-comparison from main. "
    "If the branch already exists, reuse it."
)
print(branch_result)


# Step 4: Create comparison.md on that branch and commit it
comparison_commit = await ask_agent(
    "Using the posts already retrieved in this thread for @narendramodi and @RahulGandhi, "
    "create or overwrite a file named comparison.md in my GitHub repository x-post-summarizer-2026 on branch add-comparison. "
    "Write the file in clean markdown with these sections:\n\n"
    "# Multi-Account Comparison\n"
    "## Accounts Compared\n"
    "- @narendramodi\n"
    "- @RahulGandhi\n\n"
    "## 1. Side-by-Side Topic Analysis\n"
    "## 2. Tone and Sentiment Differences\n"
    "## 3. Posting Frequency Comparison\n"
    "## 4. Top 3 Most Notable Posts from @narendramodi\n"
    "## 5. Top 3 Most Notable Posts from @RahulGandhi\n"
    "## 6. Conclusion on Each Account's Focus Area\n\n"
    "Keep the analysis neutral, observational, and based only on the retrieved posts. "
    "Then commit the file on branch add-comparison with the commit message: Add multi-account comparison."
)
print(comparison_commit)


# Step 5: Open the pull request
comparison_pr = await ask_agent(
    "Open a pull request in my GitHub repository x-post-summarizer-2026 from add-comparison to main. "
    "Set the PR title to: Add multi-account comparison. "
    "In the PR description, mention that comparison.md compares @narendramodi and @RahulGandhi across topics, tone, posting frequency, notable posts, and overall focus."
)
print(comparison_pr)
# Out:
# Here is a short summary of recent original posts from @narendramodi:
#
# 1. Focus on social welfare programs, including financial assistance and free bus travel for women in Kerala.
# 2. Emphasis on democracy, tribal community empowerment, and rural transformation.
# 3. Highlights of government initiatives like Pradhan Mantri Bhartiya Janaushadhi Pariyojana and infrastructure projects such as the Kota airport.
# 4. Engagement in international diplomacy, including discussions with world leaders like Emmanuel Macron and Alexander Stubb.
# 5. Attention to national issues such as civil services examination results, budget impacts on agriculture, and geopolitical concerns.
#
# I have also retrieved recent posts from @RahulGandhi for comparison and will remember these for later use.
#
# Let me know if you want me to analyze or compare these further.
# I have already retrieved recent original posts from @RahulGandhi along with @narendramodi in the previous step. Here is a short summary of recent original posts from @RahulGandhi:
#
# 1. Criticism of political deals and alliances in Kerala, highlighting concerns about CPM and BJP.
# 2. Advocacy for social justice and financial support for the poor, contrasting with benefits given to wealthy industrialists.
# 3. Active engagement in public meetings and dialogues with various communities in Kerala.
# 4. Emphasis on India's foreign policy rooted in history, geography, and spiritual ethos.
# 5. Concerns about global geopolitical instability and its impact on India's oil supplies and security.
#
# I have remembered these posts along with those from @narendramodi for later comparison. Let me know if you want to proceed with any analysis or further actions.
# The branch add-comparison has been created from main in your x-post-summarizer-2026 repository. If you need to add files or make changes on this branch, just let me know.
# The file comparison.md with the multi-account comparison analysis for @narendramodi and @RahulGandhi has been created in your x-post-summarizer-2026 repository on the add-comparison branch.
#
# You can view the file here: https://github.com/KrishanuSinha/x-post-summarizer-2026/blob/add-comparison/comparison.md
#
# The commit message was "Add multi-account comparison."
#
# Let me know if you want to proceed with anything else.
# I have opened a pull request in your x-post-summarizer-2026 repository from the add-comparison branch to main.
#
# Title: Add multi-account comparison
# Description: This pull request adds the comparison.md file which compares @narendramodi and @RahulGandhi across topics, tone, posting frequency, notable posts, and overall focus.
#
# You can view the pull request here: https://github.com/KrishanuSinha/x-post-summarizer-2026/pull/2
#
# Let me know if you need any further assistance.
