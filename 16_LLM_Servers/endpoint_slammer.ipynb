# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
# %pip install -U langchain-fireworks

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
# %pip install -U truststore certifi httpx langchain-fireworks
# Out:
# Requirement already satisfied: truststore in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (0.10.4)
# Requirement already satisfied: certifi in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (2026.2.25)
# Requirement already satisfied: httpx in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (0.28.1)
# Requirement already satisfied: langchain-fireworks in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (1.1.0)
# Requirement already satisfied: anyio in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from httpx) (4.12.1)
# Requirement already satisfied: httpcore==1.* in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from httpx) (1.0.9)
# Requirement already satisfied: idna in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from httpx) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from httpcore==1.*->httpx) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-fireworks) (3.13.3)
# Requirement already satisfied: fireworks-ai<1.0.0,>=0.13.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-fireworks) (0.19.20)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-fireworks) (1.2.18)
# Requirement already satisfied: openai<3.0.0,>=2.0.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-fireworks) (2.26.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-fireworks) (2.32.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-fireworks) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-fireworks) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-fireworks) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-fireworks) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-fireworks) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-fireworks) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-fireworks) (1.23.0)
# Requirement already satisfied: httpx-ws in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (0.8.2)
# Requirement already satisfied: httpx-sse in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (0.4.3)
# Requirement already satisfied: pydantic in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (2.12.5)
# Requirement already satisfied: Pillow in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (12.1.1)
# Requirement already satisfied: typing_extensions in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (4.15.0)
# Requirement already satisfied: mmh3>=4.1.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (5.2.1)
# Requirement already satisfied: betterproto-fw>=2.0.3 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (2.0.3)
# Requirement already satisfied: asyncstdlib-fw>=3.13.2 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (3.13.2)
# Requirement already satisfied: grpcio>=1.71.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (1.78.0)
# Collecting protobuf==5.29.3 (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks)
#   Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: rich>=14.0.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (14.3.3)
# Requirement already satisfied: toml>=0.10.2 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (0.10.2)
# Requirement already satisfied: googleapis-common-protos>=1.60.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (1.73.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (0.7.16)
# Requirement already satisfied: packaging>=23.2.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (0.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from openai<3.0.0,>=2.0.0->langchain-fireworks) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from openai<3.0.0,>=2.0.0->langchain-fireworks) (0.13.0)
# Requirement already satisfied: sniffio in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from openai<3.0.0,>=2.0.0->langchain-fireworks) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from openai<3.0.0,>=2.0.0->langchain-fireworks) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-fireworks) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-fireworks) (2.6.3)
# Requirement already satisfied: aiodns>=3.3.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp[speedups]>=3.12.11->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (4.0.0)
# Requirement already satisfied: Brotli>=1.2 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp[speedups]>=3.12.11->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (1.2.0)
# Requirement already satisfied: backports.zstd in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiohttp[speedups]>=3.12.11->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (1.3.0)
# Requirement already satisfied: grpclib<0.5.0,>=0.4.1 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (0.4.9)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (2.9.0.post0)
# Requirement already satisfied: ruff~=0.9.1 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (0.9.10)
# Requirement already satisfied: jinja2>=3.0.3 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (3.1.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-fireworks) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from pydantic->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from pydantic->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from pydantic->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from rich>=14.0.0->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from rich>=14.0.0->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (2.19.2)
# Requirement already satisfied: colorama in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.0.0->langchain-fireworks) (0.4.6)
# Requirement already satisfied: wsproto in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from httpx-ws->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (1.3.2)
# Requirement already satisfied: pycares<6,>=5.0.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from aiodns>=3.3.0->aiohttp[speedups]>=3.12.11->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (5.0.1)
# Requirement already satisfied: h2<5,>=3.1.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from grpclib<0.5.0,>=0.4.1->betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (4.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from jinja2>=3.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=14.0.0->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from python-dateutil<3.0.0,>=2.8.0->betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (1.17.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (4.1.0)
# Requirement already satisfied: cffi>=1.5.0 in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from pycares<6,>=5.0.0->aiodns>=3.3.0->aiohttp[speedups]>=3.12.11->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (2.0.0)
# Requirement already satisfied: pycparser in c:\myworkspace\assignments\aie9\16_llm_servers\env\lib\site-packages (from cffi>=1.5.0->pycares<6,>=5.0.0->aiodns>=3.3.0->aiohttp[speedups]>=3.12.11->fireworks-ai<1.0.0,>=0.13.0->langchain-fireworks) (3.0)
# Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.5
#     Uninstalling protobuf-6.33.5:
#       Successfully uninstalled protobuf-6.33.5
# Successfully installed protobuf-5.29.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\MyWorkspace\Assignments\AIE9\16_LLM_Servers\env\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-health-checking 1.78.0 requires protobuf<7.0.0,>=6.31.1, but you have protobuf 5.29.3 which is incompatible.
# grpcio-tools 1.78.0 requires protobuf<7.0.0,>=6.31.1, but you have protobuf 5.29.3 which is incompatible.
# langgraph-api 0.7.68 requires protobuf<7.0.0,>=6.32.1, but you have protobuf 5.29.3 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import truststore
truststore.inject_into_ssl()

# %%
import os
from langchain_fireworks import ChatFireworks

# %%
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"
llm = ChatFireworks(model=model_endpoint)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000001F087B0DB50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000001F087DB0560>

# %%
response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# It’s one of those tongue‑twister questions that never has a single “official” answer, but the popular lore gives us something to start with.
#
# In a 1988 tongue‑twister‑fanatic’s (and a bit of a huff‑and‑puff) internet‑wide survey, people guessed that a woodchuck that could actually chuck wood might manage **around 700 pounds of material** in a single, enthusiastic burrowing session (or “wood‑chucking session,” as the tongue‑twister puts it!).
#
# Why 700 lb? The estimate comes from:
#
# 1. **Burrowing data**: A woodchuck (Marmota monax) typically excavates about 25–30 cubic feet of dirt each year through burrowing in a single season.
# 2. **Density conversion**: The density of compacted dirt is roughly 90 lb per cubic foot. 25 cubic feet × 90 lb ≈ 2,250 lb.  Woodchucks do not chuck all that material in one go; they work on a much smaller “chunk” each day.
# 3. **Wood density**: Oak, which you might choose as a “standard wood,” weighs about 50–60 lb per cubic foot—roughly 70 % of the density of compacted dirt.
# 4. **Practical work rate**: If a woodchuck chips or moves about 40 cubic feet of wood in a day (a generous estimate), that’s 40 ft³ × 55 lb/ft³ ≈ **2,200 lb**. For a single chucking “session” in winter, people often round that down to a more tongue‑twister‑friendly figure—**about 700 lb**.
#
# So, if you take a whimsical, tongue‑twister‑style approach, a woodchuck that could chuck wood might *chuck roughly 700 pounds* of wood in a particularly spirited session.
#
# Of course, in reality, woodchucks (especially in the wild) chuck *nothing at all*—they love earth, not timber. 🎉

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 9 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-70def4434c424d4d9585d219c8ac3c02"}
# Request 19 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-7ed2b078e20e467b891bf1334ed651c6"}
# Request 8 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-7955f207f17f45ae8d7ced9eeac25e00"}
# Request 12 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-471c4f46509d44d7b893a10e6b15b35b"}
# Response 10: The tongue‑twister answer usually goes: **“A wood‑chuck woul...
# Response 17: How much wood?  That question has none of us lumbering out o...
# Response 24: Ah, the classic “wood‑chuck” riddle! 🎸
#
# > **Q:** How much wo...
# Response 6: The classic “tongue‑twister” answer goes:
# > **A woodchuck wo...
# Response 21: The classic tongue‑twister answer (and a bit of folklore hum...
# Response 18: That classic tongue‑twister doesn’t have a definitive scient...
# Response 2: A wood‑chuck that could chuck wood would probably only chuck...
# Response 16: **Answer:**
#
# A true “wood‑chuck” (the animal, *Marmota mona...
# Response 4: The playful “wood‑chuck” riddle has long been answered by th...
# Response 7: The classic question—“How much wood could a woodchuck chuck ...
# Response 13: In the spirit of the classic tongue‑twister, the answer is –...
# Response 14: The age‑old tongue‑twister goes:
#
# > “How much wood would a w...
# Response 1: That tongue‑twister has a long‑standing “established” answer...
# Response 23: Here’s a light‑hearted take on the classic tongue‑twister:
#
# ...
# Response 5: Ah, the classic tongue‑twister, re‑imagined as a scientific ...
# Response 3: The classic “wood‑chuck” tongue‑twister is more a playful ri...
# Response 22: ```json
# [
#   {
#     "request_id":"22",
#     "response_id":"resp...
# Response 11: The old tongue‑twister isn’t meant to be taken literally, bu...
# Response 20: 1. **A woodchuck would chuck approximately 700‑1,000 cubic f...
# Response 15: Ah, the classic tongue‑twister that’s been rattling through ...
